# %% [markdown]
# After 100 epochs, accuracy for the following are:<br>
# AdaGrad - 0.7<br>
# RMSProp - 0.725 (Heighest - 0.81)<br>
# Adam - 0.94

# %% [markdown]
# # AdaGrad Optimization
# Extension of SGD. Decay's the learning rate over time. <br>
# Hyperparameters: <br>
# lr - learning rate <br>
# eps - epsilon - default value is e**-7

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from neural_networks import Model
from neural_networks.preprocessing import one_hot_encoded

# %%
model = Model()

model.add_dense_layer(7, 4, activation='relu')
model.add_dense_layer(3, activation='softmax')

# %%
data = pd.read_csv('iris.csv')
data = shuffle(data.values)[:,1:]

# %%
split = 0.8
total = len(data)
split_index = int(total * split)

X, y = data[:,:-1], data[:,-1]
X_train, y_train = X[:split_index,].astype(float), y[:split_index,]
X_test, y_test = X[split_index:,].astype(float), y[split_index:,]

y_train = one_hot_encoded(y_train)
y_test = one_hot_encoded(y_test)

# %%
model.set_parameters(lr=0.01, loss='mse', optimization='adagrad')

# %%
model.train(X_train, y_train, 50, batch_size=12)
# Out:
# Epoch  0
# Loss:  0.1949828738167422
# Accuracy:  0.35833333333333334
#
# Epoch  1
# Loss:  0.19381324754376622
# Accuracy:  0.35833333333333334
#
# Epoch  2
# Loss:  0.19111048720986332
# Accuracy:  0.35833333333333334
#
# Epoch  3
# Loss:  0.18692181751593845
# Accuracy:  0.35833333333333334
#
# Epoch  4
# Loss:  0.180860661312403
# Accuracy:  0.35833333333333334
#
# Epoch  5
# Loss:  0.17237108841752166
# Accuracy:  0.35833333333333334
#
# Epoch  6
# Loss:  0.16102168742823927
# Accuracy:  0.35833333333333334
#
# Epoch  7
# Loss:  0.14709245783330518
# Accuracy:  0.35833333333333334
#
# Epoch  8
# Loss:  0.1321277020334804
# Accuracy:  0.36666666666666664
#
# Epoch  9
# Loss:  0.11850752920727317
# Accuracy:  0.5083333333333333
#
# Epoch  10
# Loss:  0.1080552513245299
# Accuracy:  0.6916666666666667
#
# Epoch  11
# Loss:  0.10116561632881192
# Accuracy:  0.6916666666666667
#
# Epoch  12
# Loss:  0.0970439589521518
# Accuracy:  0.6916666666666667
#
# Epoch  13
# Loss:  0.09448060694599536
# Accuracy:  0.6916666666666667
#
# Epoch  14
# Loss:  0.09244003111665357
# Accuracy:  0.6916666666666667
#
# Epoch  15
# Loss:  0.0901630063291148
# Accuracy:  0.6916666666666667
#
# Epoch  16
# Loss:  0.08707580024738336
# Accuracy:  0.6916666666666667
#
# Epoch  17
# Loss:  0.08288709879282694
# Accuracy:  0.6916666666666667
#
# Epoch  18
# Loss:  0.07800670950166251
# Accuracy:  0.6916666666666667
#
# Epoch  19
# Loss:  0.07372566386282875
# Accuracy:  0.6916666666666667
#
# Epoch  20
# Loss:  0.07113045539321276
# Accuracy:  0.6916666666666667
#
# Epoch  21
# Loss:  0.07003189914447913
# Accuracy:  0.7
#
# Epoch  22
# Loss:  0.06966870700872617
# Accuracy:  0.6916666666666667
#
# Epoch  23
# Loss:  0.06953910297969679
# Accuracy:  0.6916666666666667
#
# Epoch  24
# Loss:  0.06944816321824665
# Accuracy:  0.6833333333333333
#
# Epoch  25
# Loss:  0.06934328863914946
# Accuracy:  0.6916666666666667
#
# Epoch  26
# Loss:  0.06921825639997493
# Accuracy:  0.6833333333333333
#
# Epoch  27
# Loss:  0.0690780070115134
# Accuracy:  0.6833333333333333
#
# Epoch  28
# Loss:  0.06892836100893845
# Accuracy:  0.6833333333333333
#
# Epoch  29
# Loss:  0.06877375778350993
# Accuracy:  0.6833333333333333
#
# Epoch  30
# Loss:  0.0686171827590094
# Accuracy:  0.6833333333333333
#
# Epoch  31
# Loss:  0.06846053582186656
# Accuracy:  0.6833333333333333
#
# Epoch  32
# Loss:  0.06830498652614404
# Accuracy:  0.6833333333333333
#
# Epoch  33
# Loss:  0.06815123307344782
# Accuracy:  0.6916666666666667
#
# Epoch  34
# Loss:  0.06799967495581614
# Accuracy:  0.6916666666666667
#
# Epoch  35
# Loss:  0.06785052406084006
# Accuracy:  0.6916666666666667
#
# Epoch  36
# Loss:  0.06770387520369327
# Accuracy:  0.6916666666666667
#
# Epoch  37
# Loss:  0.06755975071934306
# Accuracy:  0.7
#
# Epoch  38
# Loss:  0.06741812865589902
# Accuracy:  0.7
#
# Epoch  39
# Loss:  0.06727896062298307
# Accuracy:  0.7
#
# Epoch  40
# Loss:  0.06714218309982596
# Accuracy:  0.7
#
# Epoch  41
# Loss:  0.06700772459165717
# Accuracy:  0.7
#
# Epoch  42
# Loss:  0.06687551013864004
# Accuracy:  0.7
#
# Epoch  43
# Loss:  0.06674546412961274
# Accuracy:  0.7
#
# Epoch  44
# Loss:  0.06661751202707042
# Accuracy:  0.7
#
# Epoch  45
# Loss:  0.06649158139193094
# Accuracy:  0.7
#
# Epoch  46
# Loss:  0.06636760245842026
# Accuracy:  0.7
#
# Epoch  47
# Loss:  0.06624550842114957
# Accuracy:  0.7
#
# Epoch  48
# Loss:  0.06612523553970552
# Accuracy:  0.7
#
# Epoch  49
# Loss:  0.06600672312935418
# Accuracy:  0.7

# %% [markdown]
# # RMSProp Optimization
# Extension of AdaGrad. Uses Exponential Moving Average of second order gradients instead of Cummulative Sum of second order gradients.<br>
# Hyperparameters: <br>
# lr - learning rate <br>
# d - decay (learning rate) <br>
# eps - epsilon - default value is e**-6

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from neural_networks import Model
from neural_networks.preprocessing import one_hot_encoded

# %%
data = pd.read_csv('iris.csv')
data = shuffle(data.values)[:,1:]

# %%
model = Model()

model.add_dense_layer(7, 4, activation='relu')
model.add_dense_layer(3, activation='softmax')

# %%
split = 0.8
total = len(data)
split_index = int(total * split)

X, y = data[:,:-1], data[:,-1]
X_train, y_train = X[:split_index,].astype(float), y[:split_index,]
X_test, y_test = X[split_index:,].astype(float), y[split_index:,]

y_train = one_hot_encoded(y_train)
y_test = one_hot_encoded(y_test)

# %%
model.set_parameters(lr=0.01, d=0.9, loss='mse', optimization='rmsprop')

# %%
model.train(X_train, y_train, 100, batch_size=12)
# Out:
# Epoch  0
# Loss:  0.13356407871759596
# Accuracy:  0.375
#
# Epoch  1
# Loss:  0.1357206282554638
# Accuracy:  0.325
#
# Epoch  2
# Loss:  0.1379813758323187
# Accuracy:  0.0
#
# Epoch  3
# Loss:  0.13565831718849883
# Accuracy:  0.016666666666666666
#
# Epoch  4
# Loss:  0.13036384720932803
# Accuracy:  0.30833333333333335
#
# Epoch  5
# Loss:  0.11984117751548047
# Accuracy:  0.35
#
# Epoch  6
# Loss:  0.09856235690278467
# Accuracy:  0.30833333333333335
#
# Epoch  7
# Loss:  0.08687260511512297
# Accuracy:  0.6583333333333333
#
# Epoch  8
# Loss:  0.08058915192707612
# Accuracy:  0.6666666666666666
#
# Epoch  9
# Loss:  0.0760009504458282
# Accuracy:  0.6666666666666666
#
# Epoch  10
# Loss:  0.07213747028858537
# Accuracy:  0.6666666666666666
#
# Epoch  11
# Loss:  0.06866365741950688
# Accuracy:  0.6666666666666666
#
# Epoch  12
# Loss:  0.0654021950450446
# Accuracy:  0.675
#
# Epoch  13
# Loss:  0.06226499475445636
# Accuracy:  0.7083333333333334
#
# Epoch  14
# Loss:  0.05927369081415109
# Accuracy:  0.7166666666666667
#
# Epoch  15
# Loss:  0.05651829135288337
# Accuracy:  0.7916666666666666
#
# Epoch  16
# Loss:  0.05377501298999516
# Accuracy:  0.8416666666666667
#
# Epoch  17
# Loss:  0.05130948189669767
# Accuracy:  0.8416666666666667
#
# Epoch  18
# Loss:  0.048937343754870584
# Accuracy:  0.8833333333333333
#
# Epoch  19
# Loss:  0.04748768476882517
# Accuracy:  0.9083333333333333
#
# Epoch  20
# Loss:  0.046583296774016604
# Accuracy:  0.9166666666666666
#
# Epoch  21
# Loss:  0.04632022777163353
# Accuracy:  0.8916666666666667
#
# Epoch  22
# Loss:  0.04609414557017978
# Accuracy:  0.8916666666666667
#
# Epoch  23
# Loss:  0.04631473241355699
# Accuracy:  0.8833333333333333
#
# Epoch  24
# Loss:  0.04667851892405218
# Accuracy:  0.8833333333333333
#
# Epoch  25
# Loss:  0.04759470581513733
# Accuracy:  0.8666666666666667
#
# Epoch  26
# Loss:  0.04825824909780462
# Accuracy:  0.825
#
# Epoch  27
# Loss:  0.04861791799928654
# Accuracy:  0.825
#
# Epoch  28
# Loss:  0.04883922785003267
# Accuracy:  0.825
#
# Epoch  29
# Loss:  0.049117826225358395
# Accuracy:  0.825
#
# Epoch  30
# Loss:  0.0495283170468296
# Accuracy:  0.8083333333333333
#
# Epoch  31
# Loss:  0.04953275434534052
# Accuracy:  0.8083333333333333
#
# Epoch  32
# Loss:  0.049817285252941594
# Accuracy:  0.8083333333333333
#
# Epoch  33
# Loss:  0.049798596253896536
# Accuracy:  0.8083333333333333
#
# Epoch  34
# Loss:  0.04966457419439201
# Accuracy:  0.8166666666666667
#
# Epoch  35
# Loss:  0.04974227237501406
# Accuracy:  0.8166666666666667
#
# Epoch  36
# Loss:  0.04981133397708893
# Accuracy:  0.8083333333333333
#
# Epoch  37
# Loss:  0.04976110916577208
# Accuracy:  0.8083333333333333
#
# Epoch  38
# Loss:  0.049738731485529264
# Accuracy:  0.8083333333333333
#
# Epoch  39
# Loss:  0.04955816069523011
# Accuracy:  0.8083333333333333
#
# Epoch  40
# Loss:  0.04966951035843948
# Accuracy:  0.8
#
# Epoch  41
# Loss:  0.04964616187282123
# Accuracy:  0.8
#
# Epoch  42
# Loss:  0.049668641630229736
# Accuracy:  0.7916666666666666
#
# Epoch  43
# Loss:  0.04966143061834291
# Accuracy:  0.7916666666666666
#
# Epoch  44
# Loss:  0.04965148490497877
# Accuracy:  0.7916666666666666
#
# Epoch  45
# Loss:  0.04964559925461307
# Accuracy:  0.7916666666666666
#
# Epoch  46
# Loss:  0.04966387784058469
# Accuracy:  0.7916666666666666
#
# Epoch  47
# Loss:  0.049758812870807856
# Accuracy:  0.7916666666666666
#
# Epoch  48
# Loss:  0.04978176652845448
# Accuracy:  0.7916666666666666
#
# Epoch  49
# Loss:  0.049873225373174526
# Accuracy:  0.7916666666666666
#
# Epoch  50
# Loss:  0.05005286050481372
# Accuracy:  0.7916666666666666
#
# Epoch  51
# Loss:  0.05006192613705346
# Accuracy:  0.7916666666666666
#
# Epoch  52
# Loss:  0.05010799675704775
# Accuracy:  0.7833333333333333
#
# Epoch  53
# Loss:  0.05016544272333766
# Accuracy:  0.7833333333333333
#
# Epoch  54
# Loss:  0.05021325308336615
# Accuracy:  0.7833333333333333
#
# Epoch  55
# Loss:  0.05028744405207964
# Accuracy:  0.7833333333333333
#
# Epoch  56
# Loss:  0.05038619292403434
# Accuracy:  0.7833333333333333
#
# Epoch  57
# Loss:  0.05027382540232156
# Accuracy:  0.7833333333333333
#
# Epoch  58
# Loss:  0.050463281729983364
# Accuracy:  0.7833333333333333
#
# Epoch  59
# Loss:  0.050573653743104865
# Accuracy:  0.7833333333333333
#
# Epoch  60
# Loss:  0.05070895172000253
# Accuracy:  0.7833333333333333
#
# Epoch  61
# Loss:  0.05087012050719751
# Accuracy:  0.7833333333333333
#
# Epoch  62
# Loss:  0.05080758297812405
# Accuracy:  0.7833333333333333
#
# Epoch  63
# Loss:  0.0511026169864926
# Accuracy:  0.775
#
# Epoch  64
# Loss:  0.05131707751189434
# Accuracy:  0.7583333333333333
#
# Epoch  65
# Loss:  0.05154400409406978
# Accuracy:  0.7583333333333333
#
# Epoch  66
# Loss:  0.05151621092826612
# Accuracy:  0.7583333333333333
#
# Epoch  67
# Loss:  0.05188664093105963
# Accuracy:  0.7583333333333333
#
# Epoch  68
# Loss:  0.052167893873603544
# Accuracy:  0.7583333333333333
#
# Epoch  69
# Loss:  0.05183119579548341
# Accuracy:  0.7583333333333333
#
# Epoch  70
# Loss:  0.05244298747828453
# Accuracy:  0.7416666666666667
#
# Epoch  71
# Loss:  0.05213130605238803
# Accuracy:  0.7583333333333333
#
# Epoch  72
# Loss:  0.05214430374949285
# Accuracy:  0.75
#
# Epoch  73
# Loss:  0.05215613190309176
# Accuracy:  0.75
#
# Epoch  74
# Loss:  0.052855534618276065
# Accuracy:  0.7333333333333333
#
# Epoch  75
# Loss:  0.05252073143332037
# Accuracy:  0.7416666666666667
#
# Epoch  76
# Loss:  0.05254175909700128
# Accuracy:  0.7416666666666667
#
# Epoch  77
# Loss:  0.05256891802768082
# Accuracy:  0.7416666666666667
#
# Epoch  78
# Loss:  0.05282367984122313
# Accuracy:  0.725
#
# Epoch  79
# Loss:  0.053152322152057126
# Accuracy:  0.7333333333333333
#
# Epoch  80
# Loss:  0.053302751141592435
# Accuracy:  0.7333333333333333
#
# Epoch  81
# Loss:  0.053398842815279964
# Accuracy:  0.7333333333333333
#
# Epoch  82
# Loss:  0.053641670224206565
# Accuracy:  0.7333333333333333
#
# Epoch  83
# Loss:  0.05393504864091802
# Accuracy:  0.725
#
# Epoch  84
# Loss:  0.05413268924650457
# Accuracy:  0.725
#
# Epoch  85
# Loss:  0.054387244147349724
# Accuracy:  0.725
#
# Epoch  86
# Loss:  0.05457749407241189
# Accuracy:  0.725
#
# Epoch  87
# Loss:  0.05478274411608104
# Accuracy:  0.725
#
# Epoch  88
# Loss:  0.0549649308008517
# Accuracy:  0.725
#
# Epoch  89
# Loss:  0.05517264607074997
# Accuracy:  0.725
#
# Epoch  90
# Loss:  0.05535642585263626
# Accuracy:  0.725
#
# Epoch  91
# Loss:  0.05551379907080322
# Accuracy:  0.725
#
# Epoch  92
# Loss:  0.05560039168943957
# Accuracy:  0.725
#
# Epoch  93
# Loss:  0.055762201362480675
# Accuracy:  0.725
#
# Epoch  94
# Loss:  0.05582745122879865
# Accuracy:  0.725
#
# Epoch  95
# Loss:  0.0559222332207041
# Accuracy:  0.725
#
# Epoch  96
# Loss:  0.05602100582784944
# Accuracy:  0.725
#
# Epoch  97
# Loss:  0.05612120051492443
# Accuracy:  0.725
#
# Epoch  98
# Loss:  0.05622127399050833
# Accuracy:  0.725
#
# Epoch  99
# Loss:  0.05631842149708032
# Accuracy:  0.725

# %% [markdown]
# # Adam Optimization
# Combination of Momentum and RMSProp. <br>
# Hyperparameters: <br>
# lr - learning rate <br>
# m - momentum (also called beta1, first order gradient parameter) <br>
# d - decay (also called beta2, second order gradient parameter) <br>
# eps - epsilon - default value is e**-8

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from neural_networks import Model
from neural_networks.preprocessing import one_hot_encoded

# %%
data = pd.read_csv('iris.csv')
data = shuffle(data.values)[:,1:]

# %%
model = Model()

model.add_dense_layer(7, 4, activation='relu')
model.add_dense_layer(3, activation='softmax')

# %%
split = 0.8
total = len(data)
split_index = int(total * split)

X, y = data[:,:-1], data[:,-1]
X_train, y_train = X[:split_index,].astype(float), y[:split_index,]
X_test, y_test = X[split_index:,].astype(float), y[split_index:,]

y_train = one_hot_encoded(y_train)
y_test = one_hot_encoded(y_test)

# %%
model.set_parameters(lr=0.01, m=0.9, d=0.999, loss='mse', optimization='adam')

# %%
model.train(X_train, y_train, 100, batch_size=12)
# Out:
# Epoch  0
# Loss:  0.11361186806402812
# Accuracy:  0.3
#
# Epoch  1
# Loss:  0.11420339254837306
# Accuracy:  0.3
#
# Epoch  2
# Loss:  0.10775412803539987
# Accuracy:  0.3
#
# Epoch  3
# Loss:  0.10339434466615018
# Accuracy:  0.225
#
# Epoch  4
# Loss:  0.09870010707967572
# Accuracy:  0.26666666666666666
#
# Epoch  5
# Loss:  0.09469002857838867
# Accuracy:  0.3
#
# Epoch  6
# Loss:  0.09153744688661841
# Accuracy:  0.6416666666666667
#
# Epoch  7
# Loss:  0.08890753610252167
# Accuracy:  0.6416666666666667
#
# Epoch  8
# Loss:  0.08662204401618186
# Accuracy:  0.6416666666666667
#
# Epoch  9
# Loss:  0.08453610754370613
# Accuracy:  0.6416666666666667
#
# Epoch  10
# Loss:  0.08258279167338904
# Accuracy:  0.6416666666666667
#
# Epoch  11
# Loss:  0.08075562842982734
# Accuracy:  0.6416666666666667
#
# Epoch  12
# Loss:  0.07905590008809388
# Accuracy:  0.65
#
# Epoch  13
# Loss:  0.07747137320371039
# Accuracy:  0.6583333333333333
#
# Epoch  14
# Loss:  0.07597976768188587
# Accuracy:  0.65
#
# Epoch  15
# Loss:  0.07456035759146971
# Accuracy:  0.6666666666666666
#
# Epoch  16
# Loss:  0.07320210200318993
# Accuracy:  0.6833333333333333
#
# Epoch  17
# Loss:  0.07190248447468861
# Accuracy:  0.7
#
# Epoch  18
# Loss:  0.07066080081307496
# Accuracy:  0.7166666666666667
#
# Epoch  19
# Loss:  0.06947378192930546
# Accuracy:  0.7583333333333333
#
# Epoch  20
# Loss:  0.06833214681011619
# Accuracy:  0.7666666666666667
#
# Epoch  21
# Loss:  0.06723326981822736
# Accuracy:  0.775
#
# Epoch  22
# Loss:  0.06618195523016797
# Accuracy:  0.7916666666666666
#
# Epoch  23
# Loss:  0.06517573008432959
# Accuracy:  0.8166666666666667
#
# Epoch  24
# Loss:  0.06420894234291427
# Accuracy:  0.8333333333333334
#
# Epoch  25
# Loss:  0.06327736794950177
# Accuracy:  0.85
#
# Epoch  26
# Loss:  0.062375683257110875
# Accuracy:  0.85
#
# Epoch  27
# Loss:  0.06151952773350322
# Accuracy:  0.8666666666666667
#
# Epoch  28
# Loss:  0.060695197633306344
# Accuracy:  0.875
#
# Epoch  29
# Loss:  0.059888657274067586
# Accuracy:  0.8833333333333333
#
# Epoch  30
# Loss:  0.059119758761050446
# Accuracy:  0.8916666666666667
#
# Epoch  31
# Loss:  0.058385267112804305
# Accuracy:  0.9
#
# Epoch  32
# Loss:  0.057653117682800896
# Accuracy:  0.9
#
# Epoch  33
# Loss:  0.056955462632767136
# Accuracy:  0.9083333333333333
#
# Epoch  34
# Loss:  0.056288317470275344
# Accuracy:  0.9083333333333333
#
# Epoch  35
# Loss:  0.055684887498040986
# Accuracy:  0.9166666666666666
#
# Epoch  36
# Loss:  0.05506116116409971
# Accuracy:  0.925
#
# Epoch  37
# Loss:  0.05443844792231933
# Accuracy:  0.925
#
# Epoch  38
# Loss:  0.053856809667533034
# Accuracy:  0.9333333333333333
#
# Epoch  39
# Loss:  0.053271666534905435
# Accuracy:  0.9333333333333333
#
# Epoch  40
# Loss:  0.05269038587914465
# Accuracy:  0.9333333333333333
#
# Epoch  41
# Loss:  0.05214924715230246
# Accuracy:  0.9333333333333333
#
# Epoch  42
# Loss:  0.05159857868229766
# Accuracy:  0.9333333333333333
#
# Epoch  43
# Loss:  0.05105115053022619
# Accuracy:  0.9333333333333333
#
# Epoch  44
# Loss:  0.05054187897193102
# Accuracy:  0.9333333333333333
#
# Epoch  45
# Loss:  0.05003323890850898
# Accuracy:  0.9333333333333333
#
# Epoch  46
# Loss:  0.04949854325537096
# Accuracy:  0.9333333333333333
#
# Epoch  47
# Loss:  0.048932356856497786
# Accuracy:  0.9333333333333333
#
# Epoch  48
# Loss:  0.048354640642276535
# Accuracy:  0.9333333333333333
#
# Epoch  49
# Loss:  0.04778505792529773
# Accuracy:  0.9333333333333333
#
# Epoch  50
# Loss:  0.04724820006019178
# Accuracy:  0.9333333333333333
#
# Epoch  51
# Loss:  0.046727722357325946
# Accuracy:  0.9333333333333333
#
# Epoch  52
# Loss:  0.04619938893798368
# Accuracy:  0.9333333333333333
#
# Epoch  53
# Loss:  0.04566971219959174
# Accuracy:  0.9333333333333333
#
# Epoch  54
# Loss:  0.045134971613682996
# Accuracy:  0.9333333333333333
#
# Epoch  55
# Loss:  0.04456539625791572
# Accuracy:  0.9333333333333333
#
# Epoch  56
# Loss:  0.04398271817200743
# Accuracy:  0.9333333333333333
#
# Epoch  57
# Loss:  0.04340515559341995
# Accuracy:  0.9333333333333333
#
# Epoch  58
# Loss:  0.042823485961668066
# Accuracy:  0.9333333333333333
#
# Epoch  59
# Loss:  0.042253630414052744
# Accuracy:  0.9333333333333333
#
# Epoch  60
# Loss:  0.04173526362040493
# Accuracy:  0.9333333333333333
#
# Epoch  61
# Loss:  0.04130753219320554
# Accuracy:  0.9333333333333333
#
# Epoch  62
# Loss:  0.04089830775941371
# Accuracy:  0.9333333333333333
#
# Epoch  63
# Loss:  0.0404576170203988
# Accuracy:  0.9333333333333333
#
# Epoch  64
# Loss:  0.04001057304024138
# Accuracy:  0.9333333333333333
#
# Epoch  65
# Loss:  0.03955950766557115
# Accuracy:  0.9333333333333333
#
# Epoch  66
# Loss:  0.03909241869666125
# Accuracy:  0.9333333333333333
#
# Epoch  67
# Loss:  0.03861382762585445
# Accuracy:  0.9333333333333333
#
# Epoch  68
# Loss:  0.03815713682480335
# Accuracy:  0.9333333333333333
#
# Epoch  69
# Loss:  0.03773886103880234
# Accuracy:  0.9333333333333333
#
# Epoch  70
# Loss:  0.037313927887848305
# Accuracy:  0.9333333333333333
#
# Epoch  71
# Loss:  0.03686987365607729
# Accuracy:  0.9333333333333333
#
# Epoch  72
# Loss:  0.036380714875841984
# Accuracy:  0.9333333333333333
#
# Epoch  73
# Loss:  0.03585520192388261
# Accuracy:  0.9416666666666667
#
# Epoch  74
# Loss:  0.03536587129423114
# Accuracy:  0.9416666666666667
#
# Epoch  75
# Loss:  0.03491586523858326
# Accuracy:  0.9416666666666667
#
# Epoch  76
# Loss:  0.03444432331779014
# Accuracy:  0.9416666666666667
#
# Epoch  77
# Loss:  0.03393546249625546
# Accuracy:  0.9416666666666667
#
# Epoch  78
# Loss:  0.0335110928737569
# Accuracy:  0.9416666666666667
#
# Epoch  79
# Loss:  0.03324277179983097
# Accuracy:  0.9416666666666667
#
# Epoch  80
# Loss:  0.032953420705014974
# Accuracy:  0.9416666666666667
#
# Epoch  81
# Loss:  0.032523601180601255
# Accuracy:  0.9416666666666667
#
# Epoch  82
# Loss:  0.032142597724074275
# Accuracy:  0.9416666666666667
#
# Epoch  83
# Loss:  0.03182522258692523
# Accuracy:  0.9416666666666667
#
# Epoch  84
# Loss:  0.03148120394288569
# Accuracy:  0.9416666666666667
#
# Epoch  85
# Loss:  0.031148848861918457
# Accuracy:  0.9416666666666667
#
# Epoch  86
# Loss:  0.030827860323072408
# Accuracy:  0.9416666666666667
#
# Epoch  87
# Loss:  0.030586347915539172
# Accuracy:  0.9416666666666667
#
# Epoch  88
# Loss:  0.030230186827931712
# Accuracy:  0.9416666666666667
#
# Epoch  89
# Loss:  0.02984088123027974
# Accuracy:  0.9416666666666667
#
# Epoch  90
# Loss:  0.029582022204657315
# Accuracy:  0.9416666666666667
#
# Epoch  91
# Loss:  0.029233907834295733
# Accuracy:  0.9416666666666667
#
# Epoch  92
# Loss:  0.028909201544918516
# Accuracy:  0.9416666666666667
#
# Epoch  93
# Loss:  0.02861862285085691
# Accuracy:  0.9416666666666667
#
# Epoch  94
# Loss:  0.02835230222811463
# Accuracy:  0.9416666666666667
#
# Epoch  95
# Loss:  0.028071614023616777
# Accuracy:  0.95
#
# Epoch  96
# Loss:  0.0276443109830131
# Accuracy:  0.9416666666666667
#
# Epoch  97
# Loss:  0.02734248389713392
# Accuracy:  0.9416666666666667
#
# Epoch  98
# Loss:  0.027171533553983274
# Accuracy:  0.9416666666666667
#
# Epoch  99
# Loss:  0.026919870168966922
# Accuracy:  0.9416666666666667
